# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
keyword = input('輸入搜尋關鍵字:')
print('搜尋: ' + keyword)
pages = int(input('輸入頁數'))
print('爬取頁數: '+ str(pages))
# Out:
# 輸入搜尋關鍵字:2
# 搜尋: 2
# 輸入頁數2
# 爬取頁數: 2

# %%
keyword = '虛擬貨幣'
pages = 6

# %%
driver_path = 'driver/chromedriver.exe'
driver = webdriver.Chrome(driver_path)

# %%
driver.get('https://search.ltn.com.tw/')
print('網頁名稱: '+ driver.title)
search = driver.find_element_by_xpath('//*[@id="keyword_search"]')
search.send_keys(keyword)
search.send_keys(Keys.RETURN)
time.sleep(2)
# Out:
# 網頁名稱: 全域查詢 - 自由時報電子報

# %%
## 新聞標題
news_title = []
## 新聞時間
dates = []
## 新聞內容
contents = []
## 新聞連結
urls = []

# %%
for i in range(pages):
    news = []
    if i != 0:
        next_button = driver.find_element_by_class_name('p_next')
        next_button.send_keys(Keys.RETURN)
    print('正在爬取第'+str(i+1)+'頁')
    time.sleep(2)
    titles = driver.find_elements_by_class_name('tit')
    for title in titles:
        news.append(title.text)
    count = 1
    for new in news:
        print('第'+str(i+1)+'頁的第'+str(count)+'則新聞')
        news_title.append(new)
        time.sleep(2)
        a = driver.find_element_by_link_text(new)
        a.send_keys(Keys.RETURN)
        time.sleep(2)
        urls.append(driver.current_url)
        time.sleep(6)
        date = driver.find_element_by_class_name("time")
        dates.append(date.text)
        time.sleep(2)
        content = driver.find_element_by_class_name('text')
        contents.append(content.text)
        time.sleep(2)
        driver.back()
        time.sleep(2)
        count+=1

result = {
          '新聞標題': news_title,
          '日期時間': dates,
          '新聞內容': contents,
          '新聞連結': urls,
          }
result_df = pd.DataFrame(result)
now = time.strftime('%Y%m%d%H%M', time.localtime())
result_df.to_csv('result/'+now+'_result.csv', encoding = 'utf-8-sig', index = False)
# Out:
# 正在爬取第1頁
# 第1頁的第1則新聞
# 第1頁的第2則新聞
# 第1頁的第3則新聞
# 第1頁的第4則新聞
# 第1頁的第5則新聞
# 第1頁的第6則新聞
# 第1頁的第7則新聞
# 第1頁的第8則新聞
# 第1頁的第9則新聞
# 第1頁的第10則新聞
# 第1頁的第11則新聞
# 第1頁的第12則新聞
# 第1頁的第13則新聞
# 第1頁的第14則新聞
# 第1頁的第15則新聞
# 第1頁的第16則新聞
# 第1頁的第17則新聞
# 第1頁的第18則新聞
# 第1頁的第19則新聞
# 第1頁的第20則新聞
# 正在爬取第2頁
# 第2頁的第1則新聞
# 第2頁的第2則新聞
# 第2頁的第3則新聞
# 第2頁的第4則新聞
# 第2頁的第5則新聞
# 第2頁的第6則新聞
# 第2頁的第7則新聞
# 第2頁的第8則新聞
# 第2頁的第9則新聞
# 第2頁的第10則新聞
# 第2頁的第11則新聞
# 第2頁的第12則新聞
# 第2頁的第13則新聞
# 第2頁的第14則新聞
# 第2頁的第15則新聞
# 第2頁的第16則新聞
# 第2頁的第17則新聞
# 第2頁的第18則新聞
# 第2頁的第19則新聞
# 第2頁的第20則新聞
# 正在爬取第3頁
# 第3頁的第1則新聞
# 第3頁的第2則新聞
# 第3頁的第3則新聞
# 第3頁的第4則新聞
# 第3頁的第5則新聞
# 第3頁的第6則新聞
# 第3頁的第7則新聞
# 第3頁的第8則新聞
# 第3頁的第9則新聞
# 第3頁的第10則新聞
# 第3頁的第11則新聞
# 第3頁的第12則新聞
# 第3頁的第13則新聞
# 第3頁的第14則新聞
# 第3頁的第15則新聞
# 第3頁的第16則新聞
# 第3頁的第17則新聞
# 第3頁的第18則新聞
# 第3頁的第19則新聞
# 第3頁的第20則新聞
# 正在爬取第4頁
# 第4頁的第1則新聞
# 第4頁的第2則新聞
# 第4頁的第3則新聞
# 第4頁的第4則新聞
# 第4頁的第5則新聞
# 第4頁的第6則新聞
# 第4頁的第7則新聞
# 第4頁的第8則新聞
# 第4頁的第9則新聞
# 第4頁的第10則新聞
# 第4頁的第11則新聞
# 第4頁的第12則新聞
# 第4頁的第13則新聞
# 第4頁的第14則新聞
# 第4頁的第15則新聞
# 第4頁的第16則新聞
# ...

# %%
result = {
          '新聞標題': news_title,
          '日期時間': dates,
          '新聞內容': contents,
          '新聞連結': urls,
          }
result_df = pd.DataFrame(result)
now = time.strftime('%Y%m%d%H%M', time.localtime())
result_df.to_csv('result/'+now+'_result.csv', encoding = 'utf-8-sig', index = False)

# %%
result_df
# Out:
#                                          新聞標題              日期時間  \
# 0            Youtuber勾惡控割韭菜 連千毅提告嗆：「你有蹲過苦窯嗎？」  2022/04/25 12:37
# 1                自由日日shoot》幣安釣魚簡訊盜帳號 虛擬貨幣瞬間轉走  2022/04/25 05:30
# 2                     自由日日shoot》釣魚簡訊 文末多附誘騙網址  2022/04/25 05:30
# 3                   假「幣安」網站發釣魚簡訊 盜投資人帳號密碼買禮物卡  2022/04/24 11:51
# 4   iPhone 詐騙新手法！接到「蘋果電話」卻因 iCloud 慘賠 1900 萬元  2022/04/22 11:30
# 5                                美再制裁俄 擴及虛擬貨幣  2022/04/22 05:30
# 6              西班牙總理抵達基輔訪問 俄宣布攻下南部港城馬立波（不斷更新）  2022/04/21 23:59
# 7                   自己國家自己救！ 烏克蘭民間發動募資 為空軍買戰機  2022/04/21 12:44
# 8                     制裁無死角 美財政部首度打擊俄虛擬貨幣挖礦公司  2022/04/21 07:24
# 9                       Whoscall示警 虛擬貨幣詐騙簡訊暴增  2022/04/21 05:30
# 10                            撤銷對俄最惠國待遇 日通過修法  2022/04/20 15:19
# 11                 釣魚簡訊「變形版」換人騙！這次小心虛擬貨幣帳戶被搬空  2022/04/20 15:14
# 12                新詐騙手法「清零」加密貨幣帳戶 未來一週恐更多釣魚簡訊  2022/04/20 14:23
# 13               台中+50！雲林龍鳳胎到台中抓周染疫 市府：應與活動無關  2022/04/19 16:38
# ...

# %%
result = {
          '新聞標題': news,
          '日期時間': dates,
          '新聞內容': contents,
          '新聞連結': urls,
          }
result_df = pd.DataFrame(result)
now = time.strftime('%Y%m%d%H%M', time.localtime())
result_df.to_csv('result/'+now+'_result.csv', encoding = 'utf-8-sig')

# %%
news = []
titles = driver.find_elements_by_class_name('tit')
for title in titles:
    news.append(title.text)
news
# Out:
# ['台中+40！西屯爆公司5人群聚 進香團男中火上班2天確診',
#  '再度向鼓鼓及孫生致歉 盧秀燕：其他13名藝人快篩都陰性',
#  '台中招商趴藝人名單搞烏龍 盧秀燕致歉鼓鼓、孫生',
#  '遭爆出席台中招商群聚感染 盧秀燕向鼓鼓道歉了',
#  '鼓鼓遭爆出席台中招商群聚感染 真相曝光喊話盧秀燕',
#  '為何馬斯克要買下推特？動機可能與美國前總統川普有關',
#  '高雄駁二「以拉號奇航」展出百幅畫作 14名插畫家直播理念',
#  '技嘉今年新品3箭齊發 全年營運估優於去年',
#  '女股神：加密貨幣、DeFi讓傳統銀行頭很大',
#  '玩家抵制成功？分析師預測一原因 GPU 顯示卡價格將「大暴跌」',
#  '比特幣會議的炫目藝術大展',
#  '傳Meta正在開發元宇宙虛幣「祖克幣」',
#  '馬斯克猛砸 765 億成推特「最大股東」！第一個許願功能要實現了',
#  '又來了！假造《自由時報》網頁 打「蔡宏圖」名號詐騙投資',
#  '詐團仿本報網頁誘投資 婦人誤信遭詐萬元美金',
#  '鄧麗君穿越時空走秀超神奇！Claudia Wang扭曲時空變仙境',
#  '陳庭妮開心不開心都「開車」! 背後原因好暖心',
#  'NFT主管機關為何？ 蘇揆承諾1個月內確定',
#  'Tiffany首發品牌虛擬貨幣！能用它買什麼引發好奇',
#  '三惡男囚禁兩名人頭帳戶賣家 沒戴口罩被警攔檢露餡']

# %%
a = driver.find_element_by_link_text('Youtuber勾惡控割韭菜 連千毅提告嗆：「你有蹲過苦窯嗎？」')
a.send_keys(Keys.RETURN)
time.sleep(2)
date = driver.find_element_by_class_name("time")
print(date.text)
# Out:
# 2022/04/25 12:37

# %%
a = driver.find_element_by_link_text('Youtuber勾惡控割韭菜 連千毅提告嗆：「你有蹲過苦窯嗎？」')
a.send_keys(Keys.RETURN)
time.sleep(2)
driver.current_url
# Out:
# 'https://news.ltn.com.tw/news/society/breakingnews/3904755'

# %%
a = driver.find_element_by_link_text('Youtuber勾惡控割韭菜 連千毅提告嗆：「你有蹲過苦窯嗎？」')
a.send_keys(Keys.RETURN)
# content = driver.find_element_by_xpath('//*[@id="ltnRWD"]/div[10]/section/div[4]/div[2]')
time.sleep(2)
content = driver.find_element_by_class_name('text')
print(content.text)
# for c in contents:
#     print(c.text)
# Out:
# 直播主連千毅。（記者王定傳攝）
# 2022/04/25 12:37
# 〔記者王定傳／新北報導〕YouTube頻道「勾起你心中的惡」（勾惡）指控直播主連千毅藉NFT斂財，根本割韭菜，連千毅不甘示弱，今日赴新北地檢署控告勾惡妨害名譽，並嗆勾惡在網路上「跳到桌子上說連千毅我要跟你怎樣怎樣」，他是能跟人家怎樣？他有蹲過苦窯嗎？充其量就是在路邊賣藝的藝人、街頭藝人，小屁孩與「8＋9」才會做這種事情，沒有意義，最後要勾惡拿下面具出來辯論，否則退出YT與直播界。
# 連千毅表示，做虛擬貨幣NFT或買股票，有漲有跌，若自己買股票最後跌到成壁紙，自己也是歡喜甘願，他不會因為買了未上市股票變成壁紙，而去控告別人騙錢。
# 請繼續往下閱讀...
# 連千毅表示，勾惡所做的影片都是斷章取義，並下聳動標題，就是要引導社會大眾先入為主；他嗆勾惡說：「大家直接把面具拿下來面對，5月5號6點，我一個人在運動場等你，如果你沒到，就退出YT跟直播界…他就直接回去跳舞就好了，當他的舞蹈老師」。
# 連千毅還加碼告發勾惡，於2017年上藝人納豆節目時，明明知道自己只是台南高分檢替代役，卻冒充警察，在節目牌子上寫著「警察」兩字，另外，勾惡在2017年成立一間資本額僅50萬元的公司，沒任何參與國家標案的競標經驗，竟可一家公司競標就拿到新北市政府城鄉局700萬元的標案，質疑有不法行為。
# 連千毅說，勾惡在網路上「跳到桌子上說連千毅我要跟你怎樣怎樣」，他是能跟人家怎樣？他有蹲過苦窯嗎？充其量就是在路邊賣藝的藝人、街頭藝人，小屁孩、「8＋9」才會做這種事情，沒有意義；他最後繼續嗆勾惡：「如果沒有膽識出來辯論，以後就叫他不要出來、不要在YT裝神弄鬼」。
# 連千毅繼續嗆勾惡應該沒錢買衣服，整天穿那套衣服、破破爛爛，「沒關係，如果你真的沒有錢買衣服的話，我送5套給你，有不同顏色的，禮拜一穿到禮拜五，再多買兩套運動服送他，不然我看他拍片永遠都穿那套，有點寒酸」。
# 不用抽 不用搶 現在用APP看新聞 保證天天中獎　 點我下載APP　 按我看活動辦法

# %%
abstract = []
content = driver.find_elements_by_xpath('//*[@id="ec"]/section/div[6]/ul/li[2]/div/p')
# print(content.text)
for c in contents:
    abstract.append(c)
abstract[0]
# Out:
# '台中地院。（資料照）\n2022/04/25 20:23\n〔記者許國楨／台中報導〕台中市陳姓男子為牟取不法利益，將歪腦筋動到虛擬貨幣上，佯稱有大量泰達幣欲交易，透過欠他錢的男子找到吳姓買家，雙方前年底相約七期重劃區一棟豪華商辦前交易，由吳交付299.5萬元給陳，但陳與同夥卻趁機落跑，案經審結，法官認定陳涉詐欺取財罪，判刑2年，沒收犯罪所得。\n全案在台中地院審理時，根據被害人、證人及同案共犯證述，以及相關微信對話紀錄，認定43歲陳男是案件主謀，佯稱欲出售泰達幣，透過「小江」協助仲介，約出被害人詐騙金額達數百萬元，不亞於一般3人以上的詐騙集團，犯後否認涉案不見悔意，還藏匿，反覆浪費司法、警政資源，加上陳有前科，依累犯加重其刑，判刑2年，另張姓共犯判刑1年6月，可上訴。\n判決指出，有恐嚇取財、殺人未遂前科的陳男，向欠債未清，綽號「小江」男子佯稱，有虛擬貨幣泰達幣欲出售，需「小江」幫忙找到買家，媒介成功會付1萬元酬金，可抵債務，「小江」不疑，前年2月20日，找來吳姓男子在七期一處豪華商辦大樓前交易，陳與張姓友人則由不知情的詹姓友人開車搭載前往赴會。\n當天吳男提領299.5萬元現金，與陳男約好以每顆泰達幣29.95元的價格購買10萬顆，吳交付現金後，陳、張在車內清點無訛，吳將電子錢包的位址，以手機軟體微信傳給「小江」，「小江」再傳給陳，讓陳將泰達幣傳送到吳的電子錢包內。\n而在等待交易確認過程，雙方共4人一起下車在超商外抽菸、聊天，但陳、張卻趁吳不備，跳上詹的轎車後，要求詹催緊油門離開，詐得299.5萬元現金，之後陳將其中27萬、20萬分給張、詹後，將其餘贓款花用殆盡，遇詐吳男事後報案，警方根據車牌以車追人循線找上詹男，詹辯稱不知情，並將分得的贓款20萬元歸還給吳，警方接著再循線查獲陳、張到案，並依詐欺取財罪送辦。\n不用抽 不用搶 現在用APP看新聞 保證天天中獎\u3000 點我下載APP\u3000 按我看活動辦法'

# %%
driver.quit()
